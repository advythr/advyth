# %% [markdown]
# **Introduction**
#
# In the Western United States, the frequency of large fires has been increasing . Fire ignitions, which are necessary for the start of new wildfires, are predominantly anthropogenic. Wildfire ignitions have increased in recent decades as human populations expand into more areas (Nagy et al., 2018). However, not all ignitions lead to large fires; ignitions during weather unfavorable to fire spread result in small fires that can be easily suppressed. Alternatively, ignitions can occur during weather conditions favorable for combustion and fire spread, which leads to rapid fire spread rates. In the absence of suppression, when suppression is limited by severe weather, or when fire spread overtakes suppression, rapid fire growth can lead to large fires.
#
# A key question in understanding and managing wildfires in the United States is where large fire frequency is increasing, and what might be causing the increase. There is evidence that climate change is increasing the incidence of weather conditions favorable to fire spread in the western US (Goss et al., 2020, Barbero et al., 2015). Whether this trend is also occurring or will occur in the Eastern US is an outstanding question. As the Eastern US has a more humid climate, wildfires typically occur during periods of drought (dry spells). It is somewhat unclear how climate change will alter drought and its ecological impacts in the Eastern US (Djajapranata, 2023), and thus whether the risk of large fires will increase in the East in the future remains unknown. The goal of this analysis is to understand how large fire frequency has changed in the United States in different regions, which provides a base point from which to hypothesize about future alterations in wildfire regimes.
#
#
# >**Sources**
# >
# >Barbero, R., Abatzoglou, J. T., Larkin, N. K., Kolden, C. A., & Stocks, B. (2015). Climate change presents increased potential for very large fires in the contiguous >United States. International Journal of Wildland Fire, 24(7), 892-899.
# >
# >Djajapranata, C. (2023, June 9). Are Wildfires Coming for the East Coast? Georgetown University. https://www.georgetown.edu/news/is-the-east-coast-the-next-wildfire-hotspot/
# >
# >Goss, M., Swain, D. L., Abatzoglou, J. T., Sarhadi, A., Kolden, C. A., Williams, A. P., & Diffenbaugh, N. S. (2020). Climate change is increasing the likelihood of extreme autumn wildfire conditions across California. Environmental Research Letters, 15(9), 094016.
# >
# >Nagy, R. C., Fusco, E., Bradley, B., Abatzoglou, J. T., & Balch, J. (2018). Human-related ignitions increase the number of large wildfires across US ecoregions. Fire, 1(1), 4.

# %%
import os
import warnings

import earthpy as et
import geopandas as gpd
import geoviews as gv
import holoviews as hv
import hvplot.pandas
import pandas as pd
import pyogrio
import matplotlib.pyplot as plt 
import numpy as np

gv.extension('bokeh')
# Out:
# <jemalloc>: MADV_DONTNEED does not work (memset will be used instead)
# <jemalloc>: (This is the expected behaviour if you are running under QEMU)
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/conda/share/proj failed
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
# ...

# %% [markdown]
# ### Ecoregions dataset

# %% [markdown]
# Bailey's ecoregions dataset contains data on ecoregions defined by the U.S. Forest Service.
#
# >**Citation**
# >
# > (dataset) (2022). Bailey's Ecoregions and Subregions Dataset. U.S. Forest Service. https://data.nal.usda.gov/dataset/baileys-ecoregions-and-subregions-dataset-0. Accessed 2023-10-19.

# %%
# Pull geoJSON directly from data.gov
ecoregions_gdf = gpd.read_file("https://data-usfs.hub.arcgis.com/datasets/usfs::baileys-ecoregions-and-subregions-dataset.geojson?outSR=%7B%22latestWkid%22%3A4269%2C%22wkid%22%3A4269%7D")

ecoregions_gdf
# Out:
#       OBJECTID   PERIMETER  ECO_US_  ECO_US_ID ECOCODE                 DOMAIN  \
# 0            1  236636.840        2         17   M127B           POLAR DOMAIN
# 1            2   94848.617        3        171   M127B           POLAR DOMAIN
# 2            3   13632.412        4        172   M127B           POLAR DOMAIN
# 3            4   14192.126        5        173   M127B           POLAR DOMAIN
# 4            5   19903.473        6        174   M127B           POLAR DOMAIN
# ...        ...         ...      ...        ...     ...                    ...
# 3067      3068    8883.945     3069       2800   -411A  HUMID TROPICAL DOMAIN
# 3068      3069   81560.000     3070        101   -411A  HUMID TROPICAL DOMAIN
# 3069      3070    7633.533     3071       2806   -411A  HUMID TROPICAL DOMAIN
# 3070      3071    5008.705     3072       2809   -411A  HUMID TROPICAL DOMAIN
# 3071      3072   31085.689     3073        101   -411A  HUMID TROPICAL DOMAIN
#
# ...

# %% [markdown]
# Test plot to check if we correctly imported the data.

# %%
ecoregions_gdf.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Spatial wildfire occurrence data for the United States
#
# Data on CONUS fire occurrence between 1992 and 2022 will be provided by <a href="https://www.fs.usda.gov/rds/archive/Catalog/RDS-2013-0009.6" target="_blank">the United States Forest Service</a>.
#
# In the Markdown cell below, write a 2-3 sentence description of the data and cite the data source.

# %% [markdown]
# The spatial wildfire occurrence dataset is generated by the United States Forest Service. The dataset contains point locations, final fire size, and discovery date for all recorded wildfires that occurred in the United States from 1992 to 2020.
#
# >**Data Citation**
# >
# >Short, Karen C. 2022. Spatial wildfire occurrence data for the United States, 1992-2020 [FPA_FOD_20221014]. 6th Edition. Fort Collins, CO: Forest Service Research Data >Archive. https://doi.org/10.2737/RDS-2013-0009.6

# %%
fire_url = (
    "https://www.fs.usda.gov/rds/archive/products/RDS-2013-0009.6/"
    "RDS-2013-0009.6_Data_Format2_GDB.zip"
)
fire_dir = et.data.get_data(url=fire_url)
fire_dir
# Out:
# ...
# Extracted output to /home/jovyan/earth-analytics/data/earthpy-downloads/RDS-2013-0009.6_Data_Format2_GDB
# '/home/jovyan/earth-analytics/data/earthpy-downloads/RDS-2013-0009.6_Data_Format2_GDB'

# %%
type(globals())
[ (key, type(value)) for key, value in globals().items()]
# Out:
# [('__name__', str),
#  ('__doc__', str),
#  ('__package__', NoneType),
#  ('__loader__', NoneType),
#  ('__spec__', NoneType),
#  ('__builtin__', module),
#  ('__builtins__', module),
#  ('_ih', list),
#  ('_oh', dict),
#  ('_dh', list),
#  ('In', list),
#  ('Out', dict),
#  ('get_ipython', method),
#  ('exit', IPython.core.autocall.ZMQExitAutocall),
#  ('quit', IPython.core.autocall.ZMQExitAutocall),
#  ('open', function),
#  ('_', str),
#  ('__', matplotlib.axes._axes.Axes),
#  ('___', geopandas.geodataframe.GeoDataFrame),
#  ('__session__', str),
#  ('_i', str),
#  ('_ii', str),
#  ('_iii', str),
#  ('_i1', str),
#  ('os', module),
#  ('warnings', module),
#  ('et', module),
#  ('gpd', module),
#  ('gv', module),
#  ('hv', module),
#  ('hvplot', module),
#  ('pd', module),
#  ('pyogrio', module),
#  ('plt', module),
#  ('np', module),
#  ('_i2', str),
#  ('ecoregions_gdf', geopandas.geodataframe.GeoDataFrame),
#  ('_2', geopandas.geodataframe.GeoDataFrame),
#  ('_i3', str),
# ...

# %%
fire_path = os.path.join(fire_dir, 'Data', 'FPA_FOD_20221014.gdb')

if not 'fire_gdf' in globals():
    print('fire_gdf does not exist. Loading...')
    fire_gdf = pyogrio.read_dataframe(fire_path, layer='Fires')
fire_gdf.head()

fire_gdf.info()
# Out:
# fire_gdf does not exist. Loading...
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2303566 entries, 0 to 2303565
# Data columns (total 38 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   FOD_ID                         int32
#  1   FPA_ID                         object
#  2   SOURCE_SYSTEM_TYPE             object
#  3   SOURCE_SYSTEM                  object
#  4   NWCG_REPORTING_AGENCY          object
#  5   NWCG_REPORTING_UNIT_ID         object
#  6   NWCG_REPORTING_UNIT_NAME       object
#  7   SOURCE_REPORTING_UNIT          object
#  8   SOURCE_REPORTING_UNIT_NAME     object
#  9   LOCAL_FIRE_REPORT_ID           object
#  10  LOCAL_INCIDENT_ID              object
#  11  FIRE_CODE                      object
#  12  FIRE_NAME                      object
#  13  ICS_209_PLUS_INCIDENT_JOIN_ID  object
#  14  ICS_209_PLUS_COMPLEX_JOIN_ID   object
#  15  MTBS_ID                        object
# ...

# %%
# Clean the fire dataset
fire_clean_gdf = (
    fire_gdf
    [['FOD_ID', 
    'DISCOVERY_DATE', 'FIRE_SIZE', 'geometry']]
    .set_index('FOD_ID')
)
# Convert discovery date to the datetime format
fire_clean_gdf.DISCOVERY_DATE = pd.to_datetime(fire_clean_gdf.DISCOVERY_DATE)

# Convert the fire_clean_gdf to the same CRS as the ecoregions
fire_clean_gdf = fire_clean_gdf.to_crs(ecoregions_gdf.crs)

fire_clean_gdf
# Out:
#           DISCOVERY_DATE  FIRE_SIZE                     geometry
# FOD_ID
# 1             2005-02-02       0.10  POINT (-121.00582 40.03694)
# 2             2004-05-12       0.25  POINT (-120.40443 38.93305)
# 3             2004-05-31       0.10  POINT (-120.73554 38.98416)
# 4             2004-06-28       0.10  POINT (-119.91332 38.55916)
# 5             2004-06-28       0.10  POINT (-119.93304 38.55916)
# ...                  ...        ...                          ...
# 400732978     2020-06-05       1.00  POINT (-108.95949 39.03788)
# 400732979     2020-07-11     100.00  POINT (-119.50304 37.14861)
# 400732980     2020-08-27      50.00  POINT (-114.44279 46.15136)
# 400732982     2020-08-17   24892.00  POINT (-120.11449 46.67033)
# 400732984     2020-11-20     105.00   POINT (-79.14845 38.57889)
#
# [2303566 rows x 3 columns]

# %%
fire_clean_gdf.plot()

# %%
# Spatial join the fires with the ecoregions
fire_region_gdf = ( 
    ecoregions_gdf
    [['ECO_US_', 'geometry']]
    .sjoin(
        fire_clean_gdf,
        how='inner', # only include rows for fires that are within an ecoregion boundary
        predicate='intersects')
)

fire_summary_gdf = (
    fire_region_gdf
        .groupby(['ECO_US_', 
                  fire_region_gdf.DISCOVERY_DATE.dt.year
                  ])
        .agg(
            max_fire_size=('FIRE_SIZE', 'max'),
            num_fires=('index_right', 'count'))
)
fire_summary_gdf

# %% [markdown]
# For the second plot, you will need to further aggregate your number of fires data, and then add the geometry of the watersheds back into the `GeoDataFrame`. We'll do this by joining the original watershed `GeoDataFrame` with a computed `DataFrame` with one value per watershed.
#
# YOUR TASK: Start with your wrangled `DataFrame` from the cell above.
#   1. Compute the total number of fires in each watershed region, saving the resulting dataframe.
#   2. Compute the area of each watershed and add it as a column to your watershed dataframe
#
#        > IMPORTANT!!!: To get an accurate **area** measurement, you should reproject to a CRS that has unites of meters instead of degrees. We recomment Albers Equal Area (EPSG:9822) because...you guessed it, it preserves area everywhere making it ideal for area calculations.
#
#   3. Join the two `DataFrame`s by 'name' using the `.join()` method
#   4. Compute the **density of fires per hectare** and add it as a column to your new joined dataframe
#   5. Simplify the geometry of your `GeoDataFrame` to speed up plotting, using `.simplify(tolerance=.1)`
#   6. Call the **column** of your GeoDataFrame (not the whole GeoDataFrame!) with  the fire density value for testing.

# %%
# Calculate area of ecoregions using the Albers equal area CRS
ecoregions_gdf['area_ha'] = (
    ecoregions_gdf.to_crs(9822).area
    # Convert to hectares
    / 10000
    # Convert to millions of hectares
    # / 1000000
)

# Computing total fires in each watershed by year
fire_count_df = (
    fire_region_gdf
    .reset_index()
    # [['ECO_US_', 'num_fires']]
    .groupby('ECO_US_', fire_region_gdf.DISCOVERY_DATE.dt.year)
    .sum()
)
fire_count_df


fire_density_gdf = (
    ecoregions_gdf.set_index('ECO_US_')
    .join(fire_count_df)
    [['num_fires', 'area_ha', 'geometry']]
)

# Create new column for fire density (number of fires in the ecoregion / total area of ecoregion)
fire_density_gdf['fire_density_per_ha'] = (
    fire_density_gdf.num_fires / fire_density_gdf.area_ha)
    
fire_density_gdf.fire_density_per_ha

# Check type of fire_density
type(fire_density_gdf)

fire_density_gdf.head()

# %% [markdown]
# ### Plot fire occurrence and size over time for each region
#
# YOUR TASK:
#   1.  Copy the following starter code into the next cell. Note that there is a function with a **full, numpy-style docstring**. You do not need to change the docstring, but take a look at its components as you will be writing these in the future. Functions are an important part of clean, **modular** code - take note of how this function is defined and how the docstring is organized.
#
# ```python
# # Set values for ylabels and titles
# labels = pd.DataFrame(dict(
#     column_name = ['max_fire_size', 'num_fires'],
#     ylabel = ['fire size ylabel', 'num fires ylabel'],
#     title = ['fire size title', 'num fires title']))
#
# def fire_plot(region_name, df=fire_df, labels=labels):
#     """
#     Create a multi-panel plot for a region
#
#     Parameters
#     ----------
#     region_name : str
#       The name of the region to generate a plot for. Must exists
#       in the 'name' index of df.
#     df : pd.DataFrame
#       The dataframe with the data to plot. Columns much match
#       an item in labels.column_name to be plotted
#     labels : pd.DataFrame
#       Plot labels. Must have a 'column_name', 'ylabel', and 'title'
#       columns with str values. Each row will be a subplot.
#
#     Returns
#     -------
#     plot : hv.core.layout.Layout
#       A holoviews plot layout or similar. For use with hv.DynamicMap.
#     """
#     # Generate a subplot for each row in the labels
#     subplots = []
#     # Iterate through the labels row by row
#     for i, labs in labels.iterrows():
#         # Create subplot
#         subplot = (
#             df.xs(region_name, level='name')
#             [[labs.column_name]]
#             .hvplot(...)
#         subplots.append(subplot)
#
#     # Stack the subplots vertically
#     plot = hv.Layout(subplots).cols(1)
#     return plot
#
# # Create a dropdown menu to switch between regions
# (
#     hv.DynamicMap(
#         # The plotting function for the two-panel fire history
#         fire_plot,
#         # Define the dimension for the dropdown
#         kdims=[('region', 'Region')])
#     # Add the explicit indexing - region names as a bokeh dimension
#     .redim.values(region=gdf.name)
# )
# ```
#   2. Change `fire_df` and `gdf` to the names of **your** fire boundaries and watershed boundary datasets.
#   3. Add parameters to the `.hvplot` method, replacing `...`. At this point you should be able to run the code.
#   4. Modify the labels `DataFrame` to get the plot labels you want
#      > HINT: you can get any value from row of the `labels` `DataFrame` the same way the `.column_name` is accessed in the sample code.
#
#      > IMPORTANT!!! When you are working with `for` loops, it is **really** helpful to print things out inside the loop. "Inside" the loop is all the lines after the start of the loop that are **indented**. For example, you could put `print(labs.ylabel)` on line 33 to see what the ylabel value for the labels `DataFrame` is for each row before using it. Or, you could print `df.xs(region_name, level='name')` to find out what that code does.

# %% [markdown]
# ### Chloropleth plot of fire density
#
# YOUR TASK: Use one of the plotting tools we have discussed (`geoviews`, `folium`, `geopandas`) to create a **chloropleth** map of the number of fires per million acres in each HUC 2 watershed in the **continental** US. A **chloropleth** map shows each shape colored by a value.
#
# > HINT: You may want to use the `gdf.geometry.simplify(tolerance=.1)` method before getting started, so that your plot renders quickly.
#
# EXTRA CHALLENGE: The Alaska Region crosses over the 0 longitude line, which causes the plot to display strangely. Can you figure out how to get your Cloropleth centered? (5 pts extra credit)

# %%
fire_density_gdf.dropna()

# Create histogram with specified bin width
# plt.hist(data, edgecolor='black', bins=np.arange(min(data), max(data) + w, w))

fire_density_gdf.hist(["fire_density_per_ha"], edgecolor='black', bins=50)

# %%
fire_density_gdf.geometry = fire_density_gdf.geometry.simplify(tolerance=0.1)

# %%
center_lon = -98.5796
center_lat = 39.8282

poly_plot = (
    gv.Polygons(
        fire_density_gdf
        .reset_index(),
        #.dropna(),
        # .dropna()[[
        #     'fire_density_per_ha', 'ECO_US_', 'geometry'
        # ]],
        vdims=['num_fires', 'ECO_US_'])
    .opts(
        width=600, height=600,
        colorbar=True, color='num_fires',
        #cmap='plasma',
        # line_color='white',
        xaxis='bare', yaxis='bare', tools=['hover']
    )
)
import cartopy.crs as ccrs
(gv.tile_sources.EsriNatGeo * poly_plot).opts(
        data_aspect=1,
        width=800
    )

# %% [markdown]
# With time slider

# %%
basemap = gv.tile_sources.EsriNatGeo

fire_sums = gv.fire_summary_gdf(cit, kdims=['City', 'Country', 'Year'])

# %% [markdown]
# ## YOUR TURN - repeat a similar analysis to answer a question of your choice about fires in the United States
#
# For example, you could:
#   * Use different regions, like states (look at data.gov or TIGRIS), or HUC-4 watersheds
#   * Calculate a different statistic, like the number of large fires over time
#   * Split the time series in two and look at the change
